# %% [markdown]
# ## Data Processing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('/content/drive/Shareddrives/FYP IDS SDN/FYP ML/InSDN_DatasetCSV/new_dataset.csv', sep=",")

# %%
condition3 = data['Label'] != 'DoS'
condition4 = data['Label'] != 'Normal'
data = data.drop(data[condition3 & condition4].index)

# %%
data['Label'] = data['Label'].replace('DoS', 1)
data['Label'] = data['Label'].replace('Normal', 0)

# %%
data = data.drop(['Flow ID','Src IP','Src Port','Dst IP', 'Dst Port', 'Timestamp'], axis=1)

# %%
data, data_test = train_test_split(data, test_size=0.2)

# %%
y_data = data["Label"]
data = data.drop(["Label"],axis=1)
y_data_test = data_test["Label"]
data_test = data_test.drop(["Label"],axis=1)

# %%
selected_features = ['Protocol', 'Tot Fwd Pkts', 'Flow Pkts/s', 'Fwd Header Len', 'Bwd Header Len', 'Bwd Pkts/s', 'Pkt Len Max', 'Init Bwd Win Byts']

# %%
data = data.drop(columns=data.columns.difference(selected_features))
data_test = data_test.drop(columns=data_test.columns.difference(selected_features))

# %%
xgb_model = xgb.XGBClassifier()
xgb_model.fit(data, y_data)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xgb_y_pred = xgb_model.predict(data_test)

# %%
mean_absolute_error(y_data_test, xgb_y_pred)
# Out:
# 0.0020485086856768275

# %%
accuracy_score(y_data_test, xgb_y_pred)
# Out:
# 0.9979514913143231

# %%
print(classification_report(y_data_test, xgb_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13754
#            1       1.00      1.00      1.00     10654
#
#     accuracy                           1.00     24408
#    macro avg       1.00      1.00      1.00     24408
# weighted avg       1.00      1.00      1.00     24408

# %%
data = pd.read_csv('/content/drive/Shareddrives/FYP IDS SDN/FYP ML/InSDN_DatasetCSV/new_dataset.csv', sep=",")

# %%
condition3 = data['Label'] != 'Probe'
condition4 = data['Label'] != 'Normal'
data = data.drop(data[condition3 & condition4].index)

# %%
data['Label'] = data['Label'].replace('Probe', 1)
data['Label'] = data['Label'].replace('Normal', 0)

# %%
data = data.drop(['Flow ID','Src IP','Src Port','Dst IP', 'Dst Port', 'Timestamp'], axis=1)

# %%
data, data_test = train_test_split(data, test_size=0.2)

# %%
y_data = data["Label"]
data = data.drop(["Label"],axis=1)
y_data_test = data_test["Label"]
data_test = data_test.drop(["Label"],axis=1)

# %%
selected_features = ['Protocol', 'Tot Fwd Pkts', 'Flow Pkts/s', 'Fwd Header Len', 'Bwd Header Len', 'Bwd Pkts/s', 'Pkt Len Max', 'Init Bwd Win Byts']
data = data.drop(columns=data.columns.difference(selected_features))
data_test = data_test.drop(columns=data_test.columns.difference(selected_features))

# %%
xgb_model_prob = xgb.XGBClassifier()
xgb_model_prob.fit(data, y_data)
xgb_y_pred_prob = xgb_model.predict(data_test)
print(classification_report(y_data_test, xgb_y_pred_prob))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73     13705
#            1       1.00      0.47      0.64     19606
#
#     accuracy                           0.69     33311
#    macro avg       0.78      0.74      0.68     33311
# weighted avg       0.82      0.69      0.68     33311

# %%
mean_absolute_error(y_data_test, xgb_y_pred_prob)
# Out:
# 0.31022785266128305

# %%
accuracy_score(y_data_test, xgb_y_pred_prob)
# Out:
# 0.689772147338717

# %% [markdown]
# ensemble

# %%
def com_mod():

# %% [markdown]
# meta lerninig

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingClassifier

base_models = [('model1', xgb_model), ('model2', xgb_model_prob)]
meta_model = xgb.XGBClassifier()# Choose another ML model for stacking

stacked_model = StackingClassifier(estimators=base_models, final_estimator=meta_model)

# %%
data = pd.read_csv('/content/drive/Shareddrives/FYP IDS SDN/FYP ML/InSDN_DatasetCSV/new_dataset.csv', sep=",")

# %%
data = data.drop(['Flow ID','Src IP','Src Port','Dst IP', 'Dst Port', 'Timestamp'], axis=1)

# %%
condition2 = data['Label'] != 'Probe'
condition3 = data['Label'] != 'DoS'
condition4 = data['Label'] != 'Normal'
data = data.drop(data[condition3 & condition4 & condition2].index)

# %%
y_data = data["Label"]
data = data.drop(["Label"],axis=1)

# %%
y_data = y_data.replace('DoS', 1)
y_data = y_data.replace('Normal', 0)
y_data = y_data.replace('Probe', 2)

# %%
selected_features = ['Protocol', 'Tot Fwd Pkts', 'Flow Pkts/s', 'Fwd Header Len', 'Bwd Header Len', 'Bwd Pkts/s', 'Pkt Len Max', 'Init Bwd Win Byts']
data = data.drop(columns=data.columns.difference(selected_features))

# %%
stacked_model.fit(data, y_data)
# Out:
# StackingClassifier(estimators=[('model1',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None, gamma=None,
#                                               gpu_id=None, grow_policy=None,
#                                               importance_type=None,
#                                               interaction_constraints=None,
#                                               learni...
#                                                  gpu_id=None, grow_policy=None,
#                                                  importance_type=None,
#                                                  interaction_constraints=None,
#                                                  learning_rate=None,
#                                                  max_bin=None,
#                                                  max_cat_threshold=None,
#                                                  max_cat_to_onehot=None,
#                                                  max_delta_step=None,
#                                                  max_depth=None,
#                                                  max_leaves=None,
#                                                  min_child_weight=None,
#                                                  missing=nan,
#                                                  monotone_constraints=None,
#                                                  n_estimators=100, n_jobs=None,
#                                                  num_parallel_tree=None,
#                                                  predictor=None,
#                                                  random_state=None, ...))

# %%
xgb_y_pred2 = stacked_model.predict(data)

# %%
print(classification_report(y_data, xgb_y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93     68424
#            1       0.97      1.00      0.98     53616
#            2       0.98      0.90      0.94     98129
#
#     accuracy                           0.95    220169
#    macro avg       0.95      0.96      0.95    220169
# weighted avg       0.95      0.95      0.95    220169
